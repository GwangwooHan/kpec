# %%
import pandas as pd
import numpy as np
import datetime
import re
from dateutil.parser import parse
import glob
import sys
import openpyxl as opx
import xlrd

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, TimeDistributed,GRU, Conv1D

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # 총발전, 총소비 데이터 추출

# %%
df1 = pd.read_csv('./211104/211104 dashboard_time_series_chart.csv', parse_dates = True)

# %%
df1['DateTime']= pd.to_datetime(df1['DateTime'])

# %%
df1=df1[(df1['DateTime']>='2021-09-13 00:00:00')]

# %%
df1=df1[(df1['DateTime']<'2021-11-04 00:00:00')]

# %%
df1
# Out:
#                  DateTime  energyTotalProduce  energyTotalConsume  ToESS(We)  \
# 20469 2021-09-13 00:00:00               9.869             6694.41    118.000
# 20470 2021-09-13 00:03:00               9.334             6440.19    112.667
# 20471 2021-09-13 00:06:00               9.667             5711.75    112.333
# 20472 2021-09-13 00:07:00               9.464             5851.42    112.643
# 20473 2021-09-13 00:08:00               9.766             6590.12    112.310
# ...                   ...                 ...                 ...        ...
# 77303 2021-11-03 23:55:00             569.283             7573.30      0.000
# 77304 2021-11-03 23:56:00             567.933             7719.92      0.000
# 77305 2021-11-03 23:57:00             567.933             7962.67      0.000
# 77306 2021-11-03 23:58:00             569.500             8019.32      0.000
# 77307 2021-11-03 23:59:00             569.100             8394.18      0.000
#
#        ESSout(We)  energyTotalSelfConsumeRate  energyTotalSelfRate  SCF  \
# 20469         0.0                         1.0             0.240607  0.0
# 20470         0.0                         1.0             0.240602  0.0
# 20471         0.0                         1.0             0.240589  0.0
# 20472         0.0                         1.0             0.240584  0.0
# 20473         0.0                         1.0             0.240579  0.0
# ...           ...                         ...                  ...  ...
# 77303         0.0                         1.0             0.714178  1.0
# 77304         0.0                         1.0             0.714173  1.0
# 77305         0.0                         1.0             0.714168  1.0
# 77306         0.0                         1.0             0.714162  1.0
# 77307         0.0                         1.0             0.714157  1.0
#
#             LCF  SCF_acc   LCF_acc
# 20469  0.000000        0  0.000000
# 20470  0.000000        0  0.000000
# 20471  0.000000        0  0.000000
# 20472  0.000000        0  0.000000
# 20473  0.000000        0  0.000000
# ...         ...      ...       ...
# 77303  0.075170        1  0.366645
# 77304  0.073567        1  0.366642
# 77305  0.071324        1  0.366640
# 77306  0.071016        1  0.366638
# 77307  0.067797        1  0.366635
#
# [56839 rows x 11 columns]

# %% [markdown]
# # ESS충방전량 추출

# %%
df2 = pd.read_csv('./211104/211104 kepsh1.csv', parse_dates = True)

# %%
df2['DateTime']= pd.to_datetime(df2['DateTime'])

# %%
df2=df2[(df2['DateTime']>='2021-09-13 00:00:00')]

# %%
df2=df2[(df2['DateTime']<'2021-11-04 00:00:00')]

# %%
df2
# Out:
#                   DateTime  Room_Temp(�C)  T1(�C)  T2(�C)  T3(�C)  T4(�C)  \
# 158524 2021-09-13 00:00:00           26.5  38.975  36.197  25.940  23.875
# 158525 2021-09-13 00:03:00           26.5  38.988  36.235  26.104  24.017
# 158526 2021-09-13 00:04:00           26.5  38.972  36.238  26.165  24.061
# 158527 2021-09-13 00:05:00           26.5  38.966  36.220  26.222  24.125
# 158528 2021-09-13 00:06:00           26.5  38.980  36.217  26.281  24.180
# ...                    ...            ...     ...     ...     ...     ...
# 223885 2021-11-03 23:55:00           26.1  33.109  33.380  31.618  30.754
# 223886 2021-11-03 23:56:00           26.1  33.110  33.381  31.586  30.731
# 223887 2021-11-03 23:57:00           26.1  33.108  33.378  31.565  30.708
# 223888 2021-11-03 23:58:00           26.1  33.106  33.372  31.538  30.685
# 223889 2021-11-03 23:59:00           26.1  33.111  33.369  31.507  30.667
#
#         T5(�C)   T6(�C)  T8(�C)  T9(�C)  ...  Pvt_Supply(W)  Pv_Supply(W)  \
# 158524  27.271  100.000  25.158  45.849  ...            9.0         -49.0
# 158525  27.390  100.000  25.140  45.847  ...            9.0         -49.0
# 158526  27.433  100.000  25.146  45.857  ...            9.0         -49.0
# 158527  27.480  100.000  25.128  45.843  ...            9.0         -49.0
# 158528  27.529  100.000  25.160  45.854  ...            9.0         -49.0
# ...        ...      ...     ...     ...  ...            ...           ...
# 223885  31.927   30.845  19.279  53.002  ...           -9.0         -50.0
# 223886  31.907   30.812  19.283  53.003  ...           -9.0         -50.0
# 223887  31.888   30.785  19.282  52.997  ...           -9.0         -50.0
# 223888  31.866   30.763  19.277  52.989  ...           -9.0         -50.0
# 223889  31.842   30.742  19.288  52.996  ...           -9.0         -50.0
#
#         Heatpump_Load(W)  FuelCell_Supply(W)  WS_Temperature(�C)  \
# 158524              29.0                 0.0                22.0
# 158525              29.0                 0.0                22.0
# 158526              29.0                 0.0                22.0
# 158527              28.0                 0.0                22.0
# 158528              29.0                 0.0                22.0
# ...                  ...                 ...                 ...
# 223885              29.0               569.0                17.0
# 223886              29.0               568.0                17.0
# 223887              29.0               568.0                17.0
# 223888              29.0               570.0                17.0
# 223889              29.0               569.0                17.0
#
#         WS_SolarRadiation(w/m�)  WS_WindDirection_Slope(w/m�)  \
# 158524                      0.0                           0.0
# 158525                      0.0                           0.0
# 158526                      0.0                           0.0
# 158527                      0.0                           0.0
# 158528                      0.0                           0.0
# ...                         ...                           ...
# 223885                     13.4                           0.0
# 223886                     13.4                           0.0
# 223887                     13.4                           0.0
# 223888                     13.4                           0.0
# 223889                     13.4                           0.0
#
#         Thermal_Operation_Mode  Total_Consumption(W)  Total_Production(W)
# 158524                     0.0                   677                    9
# 158525                     0.0                   674                    9
# 158526                     0.0                   780                    9
# 158527                     0.0                   806                    9
# 158528                     0.0                   797                    9
# ...                        ...                   ...                  ...
# 223885                     0.0                   892                  569
# 223886                     0.0                   896                  568
# 223887                     0.0                   897                  568
# 223888                     0.0                   892                  570
# 223889                     0.0                   888                  569
#
# [65366 rows x 27 columns]

# %% [markdown]
# # ToGrid 데이터 추출

# %%
df3 = pd.read_csv('./211104/211104 dashboard_facility_enegy_flow.csv', parse_dates = True)

# %%
df3['DateTime']= pd.to_datetime(df3['DateTime'])

# %%
df3=df3[(df3['DateTime']>='2021-09-13 00:00:00')]

# %%
df3=df3[(df3['DateTime']<'2021-11-04 00:00:00')]

# %%
df3
# Out:
#                  DateTime  PVout(We)  PVTout(We)  FCout(We)  PlugLoad(We)  \
# 3115  2021-09-13 00:04:00    -80.638       9.414      0.000       2626.05
# 3116  2021-09-13 00:06:00    -78.139       9.667      0.000       2492.71
# 3117  2021-09-13 00:08:00    -79.959       9.552      0.000       2394.03
# 3118  2021-09-13 00:10:00    -79.772       9.541      0.000       2417.50
# 3119  2021-09-13 00:11:00    -79.579       9.421      0.000       2398.74
# ...                   ...        ...         ...        ...           ...
# 57736 2021-11-03 23:55:00    -82.800     -74.267    569.233       6000.10
# 57737 2021-11-03 23:56:00    -82.867     -74.600    567.933       6016.00
# 57738 2021-11-03 23:57:00    -82.717     -74.600    567.933       5963.23
# 57739 2021-11-03 23:58:00    -82.717     -74.400    569.500       6032.48
# 57740 2021-11-03 23:59:00    -83.100     -74.767    569.100       6414.50
#
#        LightLoad(We)  FromGrid(We)  ToGrid(We)  ToESS(We)  ESSout(We)  ...  \
# 3115         649.629       6360.67         0.0    112.672         0.0  ...
# 3116         640.722       5702.08         0.0    112.333         0.0  ...
# 3117         641.167       6580.36         0.0    112.310         0.0  ...
# 3118         652.340       8362.08         0.0    112.730         0.0  ...
# 3119         690.117       7620.11         0.0    112.474         0.0  ...
# ...              ...           ...         ...        ...         ...  ...
# 57736       1339.370       7004.02         0.0      0.000         0.0  ...
# 57737       1470.630       7151.98         0.0      0.000         0.0  ...
# 57738       1765.020       7394.73         0.0      0.000         0.0  ...
# 57739       1751.720       7449.82         0.0      0.000         0.0  ...
# 57740       1745.220       7825.08         0.0      0.000         0.0  ...
#
#        GSHP2HTES(Wt)  ASHP2Cool(Wt)  ASHP2Heat(Wt)  CTES2Cool(Wt)  \
# 3115             0.0        2393.78            0.0           0.00
# 3116             0.0        2436.01            0.0           0.00
# 3117             0.0        2497.65            0.0           0.00
# 3118             0.0        2439.18            0.0        9162.40
# 3119             0.0        2462.05            0.0        5654.57
# ...              ...            ...            ...            ...
# 57736            0.0           0.00            0.0           0.00
# 57737            0.0           0.00            0.0           0.00
# 57738            0.0           0.00            0.0           0.00
# 57739            0.0           0.00            0.0           0.00
# 57740            0.0           0.00            0.0           0.00
#
#        HTES2Heat(Wt)  HTES2Water(Wt)  DirectElec(We)  CoolLoad(Wt)  \
# 3115             0.0             0.0         3275.68       2393.78
# 3116             0.0             0.0         3133.43       2436.01
# 3117             0.0             0.0         3035.20       2497.65
# 3118             0.0             0.0         3069.84      11601.60
# 3119             0.0             0.0         3088.86       8116.63
# ...              ...             ...             ...           ...
# 57736            0.0             0.0         7339.47          0.00
# 57737            0.0             0.0         7486.64          0.00
# 57738            0.0             0.0         7728.25          0.00
# 57739            0.0             0.0         7784.20          0.00
# 57740            0.0             0.0         8159.72          0.00
#
#        HeatLoad(Wt)  HotwaterLoad(Wt)
# 3115            0.0               0.0
# 3116            0.0               0.0
# 3117            0.0               0.0
# 3118            0.0               0.0
# 3119            0.0               0.0
# ...             ...               ...
# 57736           0.0               0.0
# 57737           0.0               0.0
# 57738           0.0               0.0
# 57739           0.0               0.0
# 57740           0.0               0.0
#
# [54626 rows x 29 columns]

# %% [markdown]
# # KPEC 합치기

# %%
df_kpec = pd.DataFrame()
df_kpec['Time'] = df2['DateTime']

# %%
df_kpec=df_kpec.set_index('Time')
df1=df1.set_index('DateTime')
df2=df2.set_index('DateTime')
df3=df3.set_index('DateTime')

# %%
df_kpec['Cons_kpec(W)'] = df1['energyTotalConsume']
df_kpec['Prod_kpec(W)'] = df1['energyTotalProduce']
df_kpec['ESS_kpec(W)'] = df2['ESS_Power(W)']*(-1)

# %%
df_kpec['PV_kpec(We)'] = df3['PVout(We)']
df_kpec['PVT_kpec(We)'] = df3['PVTout(We)']
df_kpec['FC_kpec(We)'] = df3['FCout(We)']
df_kpec['PlugLoad(We)'] = df3['PlugLoad(We)']
df_kpec['LightLoad(We)'] = df3['LightLoad(We)']
df_kpec['FromGrid(We)'] = df3['FromGrid(We)']
df_kpec['ToGrid(We)'] = df3['ToGrid(We)']
df_kpec['ToESS(We)'] = df3['ToESS(We)']
df_kpec['ESSout(We)'] = df3['ESSout(We)']
df_kpec['ESS2Grid(We)'] = df3['ESS2Grid(We)']
df_kpec['ESS2ASHP(We)'] = df3['ESS2ASHP(We)']
df_kpec['ESS2GSHP(We)'] = df3['ESS2GSHP(We)']
df_kpec['Grid2ASHP(We)'] = df3['Grid2ASHP(We)']
df_kpec['Grid2GSHP(We)'] = df3['Grid2GSHP(We)']
df_kpec['PVTHout(Wt)'] = df3['PVTHout(Wt)']
df_kpec['FCHout(Wt)'] = df3['FCHout(Wt)']
df_kpec['ASHP2HTES(Wt)'] = df3['ASHP2HTES(Wt)']
df_kpec['GSHP2CTES(Wt)'] = df3['GSHP2CTES(Wt)']
df_kpec['GSHP2HTES(Wt)'] = df3['GSHP2HTES(Wt)']
df_kpec['ASHP2Cool(Wt)'] = df3['ASHP2Cool(Wt)']
df_kpec['ASHP2Heat(Wt)'] = df3['ASHP2Heat(Wt)']
df_kpec['CTES2Cool(Wt)'] = df3['CTES2Cool(Wt)']
df_kpec['HTES2Heat(Wt)'] = df3['HTES2Heat(Wt)']
df_kpec['HTES2Water(Wt)'] = df3['HTES2Water(Wt)']
df_kpec['DirectElec(We)'] = df3['DirectElec(We)']
df_kpec['CoolLoad(Wt)'] = df3['CoolLoad(Wt)']
df_kpec['HeatLoad(Wt)'] = df3['HeatLoad(Wt)']
df_kpec['HotwaterLoad(Wt)'] = df3['HotwaterLoad(Wt)']

# %%
df_kpec['PV_kpec(We)'] = np.where(df_kpec['PV_kpec(We)']<0, 0, df_kpec['PV_kpec(We)'])
df_kpec['PVT_kpec(We)'] = np.where(df_kpec['PVT_kpec(We)']<0, 0, df_kpec['PVT_kpec(We)'])
df_kpec['FC_kpec(We)'] = np.where(df_kpec['FC_kpec(We)']<0, 0, df_kpec['FC_kpec(We)'])
df_kpec['PlugLoad(We)'] = np.where(df_kpec['PlugLoad(We)']<0, 0, df_kpec['PlugLoad(We)'])

# %%
df_kpec = df_kpec[df_kpec['Cons_kpec(W)']< 40000]

# %%
df_kpec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 55924 entries, 2021-09-13 00:00:00 to 2021-11-03 23:59:00
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cons_kpec(W)      55924 non-null  float64
#  1   Prod_kpec(W)      55924 non-null  float64
#  2   ESS_kpec(W)       55924 non-null  float64
#  3   PV_kpec(We)       53816 non-null  float64
#  4   PVT_kpec(We)      53816 non-null  float64
#  5   FC_kpec(We)       53816 non-null  float64
#  6   PlugLoad(We)      53816 non-null  float64
#  7   LightLoad(We)     53816 non-null  float64
#  8   FromGrid(We)      53816 non-null  float64
#  9   ToGrid(We)        53816 non-null  float64
#  10  ToESS(We)         53816 non-null  float64
#  11  ESSout(We)        53816 non-null  float64
#  12  ESS2Grid(We)      53816 non-null  float64
#  13  ESS2ASHP(We)      53816 non-null  float64
#  14  ESS2GSHP(We)      53816 non-null  float64
#  15  Grid2ASHP(We)     53816 non-null  float64
#  16  Grid2GSHP(We)     53816 non-null  float64
#  17  PVTHout(Wt)       53816 non-null  float64
#  18  FCHout(Wt)        53816 non-null  float64
#  19  ASHP2HTES(Wt)     53816 non-null  float64
#  20  GSHP2CTES(Wt)     53816 non-null  float64
#  21  GSHP2HTES(Wt)     53816 non-null  float64
#  22  ASHP2Cool(Wt)     53816 non-null  float64
#  23  ASHP2Heat(Wt)     53816 non-null  float64
#  24  CTES2Cool(Wt)     53816 non-null  float64
#  25  HTES2Heat(Wt)     53816 non-null  float64
#  26  HTES2Water(Wt)    53816 non-null  float64
#  27  DirectElec(We)    53816 non-null  float64
#  28  CoolLoad(Wt)      53816 non-null  float64
#  29  HeatLoad(Wt)      53816 non-null  float64
#  30  HotwaterLoad(Wt)  53816 non-null  float64
# dtypes: float64(31)
# memory usage: 13.7 MB

# %%
df_kpec=df_kpec.dropna()

# %%
df_kpec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53816 entries, 2021-09-13 00:06:00 to 2021-11-03 23:59:00
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cons_kpec(W)      53816 non-null  float64
#  1   Prod_kpec(W)      53816 non-null  float64
#  2   ESS_kpec(W)       53816 non-null  float64
#  3   PV_kpec(We)       53816 non-null  float64
#  4   PVT_kpec(We)      53816 non-null  float64
#  5   FC_kpec(We)       53816 non-null  float64
#  6   PlugLoad(We)      53816 non-null  float64
#  7   LightLoad(We)     53816 non-null  float64
#  8   FromGrid(We)      53816 non-null  float64
#  9   ToGrid(We)        53816 non-null  float64
#  10  ToESS(We)         53816 non-null  float64
#  11  ESSout(We)        53816 non-null  float64
#  12  ESS2Grid(We)      53816 non-null  float64
#  13  ESS2ASHP(We)      53816 non-null  float64
#  14  ESS2GSHP(We)      53816 non-null  float64
#  15  Grid2ASHP(We)     53816 non-null  float64
#  16  Grid2GSHP(We)     53816 non-null  float64
#  17  PVTHout(Wt)       53816 non-null  float64
#  18  FCHout(Wt)        53816 non-null  float64
#  19  ASHP2HTES(Wt)     53816 non-null  float64
#  20  GSHP2CTES(Wt)     53816 non-null  float64
#  21  GSHP2HTES(Wt)     53816 non-null  float64
#  22  ASHP2Cool(Wt)     53816 non-null  float64
#  23  ASHP2Heat(Wt)     53816 non-null  float64
#  24  CTES2Cool(Wt)     53816 non-null  float64
#  25  HTES2Heat(Wt)     53816 non-null  float64
#  26  HTES2Water(Wt)    53816 non-null  float64
#  27  DirectElec(We)    53816 non-null  float64
#  28  CoolLoad(Wt)      53816 non-null  float64
#  29  HeatLoad(Wt)      53816 non-null  float64
#  30  HotwaterLoad(Wt)  53816 non-null  float64
# dtypes: float64(31)
# memory usage: 13.1 MB

# %%
df_kpec=df_kpec.resample('1T').mean()

# %%
df_kpec['Cons_acc_kpec(Wh)'] = df_kpec['Cons_kpec(W)'].cumsum()*60*1/3600
df_kpec['Prod_acc_kpec(Wh)'] = df_kpec['Prod_kpec(W)'].cumsum()*60*1/3600
df_kpec['ESS_acc_kpec(Wh)'] = df_kpec['ESS_kpec(W)'].cumsum()*60*1/3600

df_kpec['PV_acc_kpec(Wh)'] = df_kpec['PV_kpec(We)'].cumsum()*60*1/3600
df_kpec['PVT_acc_kpec(Wh)'] = df_kpec['PVT_kpec(We)'].cumsum()*60*1/3600
df_kpec['FC_acc_kpec(Wh)'] = df_kpec['FC_kpec(We)'].cumsum()*60*1/3600
df_kpec['PlugLoad_acc(Wh)'] = df_kpec['PlugLoad(We)'].cumsum()*60*1/3600
df_kpec['LightLoad_acc(Wh)'] = df_kpec['LightLoad(We)'].cumsum()*60*1/3600
df_kpec['FromgGrid_acc(Wh)'] = df_kpec['FromGrid(We)'].cumsum()*60*1/3600
df_kpec['ToGrid_acc(Wh)'] = df_kpec['ToGrid(We)'].cumsum()*60*1/3600
df_kpec['ToESS_acc(Wh)'] = df_kpec['ToESS(We)'].cumsum()*60*1/3600
df_kpec['ESSout_acc(Wh)'] = df_kpec['ESSout(We)'].cumsum()*60*1/3600
df_kpec['ESS2Grid_acc(Wh)'] = df_kpec['ESS2Grid(We)'].cumsum()*60*1/3600
df_kpec['ESS2ASHP_acc(Wh)'] = df_kpec['ESS2ASHP(We)'].cumsum()*60*1/3600
df_kpec['ESS2GSHP_acc(Wh)'] = df_kpec['ESS2GSHP(We)'].cumsum()*60*1/3600
df_kpec['Grid2ASHP_acc(Wh)'] = df_kpec['Grid2ASHP(We)'].cumsum()*60*1/3600
df_kpec['Grid2GSHP_acc(Wh)'] = df_kpec['Grid2GSHP(We)'].cumsum()*60*1/3600
df_kpec['PVTHout_acc(Wh)'] = df_kpec['PVTHout(Wt)'].cumsum()*60*1/3600
df_kpec['FCHout_acc(Wh)'] = df_kpec['FCHout(Wt)'].cumsum()*60*1/3600
df_kpec['ASHP2HTES_acc(Wh)'] = df_kpec['ASHP2HTES(Wt)'].cumsum()*60*1/3600
df_kpec['GSHP2CTES_acc(Wh)'] = df_kpec['GSHP2CTES(Wt)'].cumsum()*60*1/3600
df_kpec['GSHP2HTES_acc(Wh)'] = df_kpec['GSHP2HTES(Wt)'].cumsum()*60*1/3600
df_kpec['ASHP2Cool_acc(Wh)'] = df_kpec['ASHP2Cool(Wt)'].cumsum()*60*1/3600
df_kpec['ASHP2Heat_acc(Wh)'] = df_kpec['ASHP2Heat(Wt)'].cumsum()*60*1/3600
df_kpec['CTES2Cool_acc(Wh)'] = df_kpec['CTES2Cool(Wt)'].cumsum()*60*1/3600
df_kpec['HTES2Heat_acc(Wh)'] = df_kpec['HTES2Heat(Wt)'].cumsum()*60*1/3600
df_kpec['HTES2Water_acc(Wh)'] = df_kpec['HTES2Water(Wt)'].cumsum()*60*1/3600
df_kpec['DirectElec_acc(Wh)'] = df_kpec['DirectElec(We)'].cumsum()*60*1/3600
df_kpec['CoolLoad_acc(Wh)'] = df_kpec['CoolLoad(Wt)'].cumsum()*60*1/3600
df_kpec['HeatLoad_acc(Wh)'] = df_kpec['HeatLoad(Wt)'].cumsum()*60*1/3600
df_kpec['HotwaterLoad_acc(Wh)'] = df_kpec['HotwaterLoad(Wt)'].cumsum()*60*1/3600

# %%
df_kpec['E_self(W)'] = df_kpec['Prod_kpec(W)'] - df_kpec['ESS_kpec(W)'] - df_kpec['ToGrid(We)']
df_kpec['E_self_acc(Wh)'] =df_kpec['E_self(W)'].cumsum()*60*1/3600

# %%
df_kpec['denominator'] = df_kpec.loc[:,['E_self(W)','Cons_kpec(W)']].min(axis=1)
df_kpec['denominator_acc'] = df_kpec.loc[:,['E_self_acc(Wh)','Cons_acc_kpec(Wh)']].min(axis=1)

# %%
df_kpec['SCF'] = df_kpec['denominator']/(df_kpec['Prod_kpec(W)'] - df_kpec['ESS_kpec(W)'])
df_kpec['LCF'] = df_kpec['denominator']/df_kpec['Cons_kpec(W)']

# %%
df_kpec['SCF_acc'] = df_kpec['denominator_acc']/(df_kpec['Prod_acc_kpec(Wh)'] - df_kpec['ESS_acc_kpec(Wh)'])
df_kpec['LCF_acc'] = df_kpec['denominator_acc']/df_kpec['Cons_acc_kpec(Wh)']

# %%
df_kpec['self_sustain'] = df_kpec['Prod_acc_kpec(Wh)']/df_kpec['Cons_acc_kpec(Wh)']
df_kpec['Avg_SCF&LCF']=(df_kpec['SCF_acc']+df_kpec['LCF_acc'])/2

# %%
df_kpec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 74874 entries, 2021-09-13 00:06:00 to 2021-11-03 23:59:00
# Freq: T
# Data columns (total 72 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Cons_kpec(W)          53816 non-null  float64
#  1   Prod_kpec(W)          53816 non-null  float64
#  2   ESS_kpec(W)           53816 non-null  float64
#  3   PV_kpec(We)           53816 non-null  float64
#  4   PVT_kpec(We)          53816 non-null  float64
#  5   FC_kpec(We)           53816 non-null  float64
#  6   PlugLoad(We)          53816 non-null  float64
#  7   LightLoad(We)         53816 non-null  float64
#  8   FromGrid(We)          53816 non-null  float64
#  9   ToGrid(We)            53816 non-null  float64
#  10  ToESS(We)             53816 non-null  float64
#  11  ESSout(We)            53816 non-null  float64
#  12  ESS2Grid(We)          53816 non-null  float64
#  13  ESS2ASHP(We)          53816 non-null  float64
#  14  ESS2GSHP(We)          53816 non-null  float64
#  15  Grid2ASHP(We)         53816 non-null  float64
#  16  Grid2GSHP(We)         53816 non-null  float64
#  17  PVTHout(Wt)           53816 non-null  float64
#  18  FCHout(Wt)            53816 non-null  float64
#  19  ASHP2HTES(Wt)         53816 non-null  float64
#  20  GSHP2CTES(Wt)         53816 non-null  float64
#  21  GSHP2HTES(Wt)         53816 non-null  float64
#  22  ASHP2Cool(Wt)         53816 non-null  float64
#  23  ASHP2Heat(Wt)         53816 non-null  float64
#  24  CTES2Cool(Wt)         53816 non-null  float64
#  25  HTES2Heat(Wt)         53816 non-null  float64
#  26  HTES2Water(Wt)        53816 non-null  float64
#  27  DirectElec(We)        53816 non-null  float64
#  28  CoolLoad(Wt)          53816 non-null  float64
#  29  HeatLoad(Wt)          53816 non-null  float64
#  30  HotwaterLoad(Wt)      53816 non-null  float64
#  31  Cons_acc_kpec(Wh)     53816 non-null  float64
#  32  Prod_acc_kpec(Wh)     53816 non-null  float64
#  33  ESS_acc_kpec(Wh)      53816 non-null  float64
#  34  PV_acc_kpec(Wh)       53816 non-null  float64
#  35  PVT_acc_kpec(Wh)      53816 non-null  float64
#  36  FC_acc_kpec(Wh)       53816 non-null  float64
#  37  PlugLoad_acc(Wh)      53816 non-null  float64
#  38  LightLoad_acc(Wh)     53816 non-null  float64
#  39  FromgGrid_acc(Wh)     53816 non-null  float64
#  40  ToGrid_acc(Wh)        53816 non-null  float64
#  41  ToESS_acc(Wh)         53816 non-null  float64
#  42  ESSout_acc(Wh)        53816 non-null  float64
#  43  ESS2Grid_acc(Wh)      53816 non-null  float64
#  44  ESS2ASHP_acc(Wh)      53816 non-null  float64
#  45  ESS2GSHP_acc(Wh)      53816 non-null  float64
#  46  Grid2ASHP_acc(Wh)     53816 non-null  float64
#  47  Grid2GSHP_acc(Wh)     53816 non-null  float64
#  48  PVTHout_acc(Wh)       53816 non-null  float64
#  49  FCHout_acc(Wh)        53816 non-null  float64
#  50  ASHP2HTES_acc(Wh)     53816 non-null  float64
#  51  GSHP2CTES_acc(Wh)     53816 non-null  float64
#  52  GSHP2HTES_acc(Wh)     53816 non-null  float64
#  53  ASHP2Cool_acc(Wh)     53816 non-null  float64
#  54  ASHP2Heat_acc(Wh)     53816 non-null  float64
#  55  CTES2Cool_acc(Wh)     53816 non-null  float64
#  56  HTES2Heat_acc(Wh)     53816 non-null  float64
#  57  HTES2Water_acc(Wh)    53816 non-null  float64
#  58  DirectElec_acc(Wh)    53816 non-null  float64
#  59  CoolLoad_acc(Wh)      53816 non-null  float64
#  60  HeatLoad_acc(Wh)      53816 non-null  float64
#  61  HotwaterLoad_acc(Wh)  53816 non-null  float64
#  62  E_self(W)             53816 non-null  float64
#  63  E_self_acc(Wh)        53816 non-null  float64
#  64  denominator           53816 non-null  float64
#  65  denominator_acc       53816 non-null  float64
#  66  SCF                   53816 non-null  float64
#  67  LCF                   53816 non-null  float64
#  68  SCF_acc               53816 non-null  float64
#  69  LCF_acc               53816 non-null  float64
#  70  self_sustain          53816 non-null  float64
#  71  Avg_SCF&LCF           53816 non-null  float64
# dtypes: float64(72)
# memory usage: 41.7 MB

# %%
df_kpec
# Out:
#                      Cons_kpec(W)  Prod_kpec(W)  ESS_kpec(W)  PV_kpec(We)  \
# Time
# 2021-09-13 00:06:00       5711.75         9.667          0.0          0.0
# 2021-09-13 00:07:00           NaN           NaN          NaN          NaN
# 2021-09-13 00:08:00       6590.12         9.766          0.0          0.0
# 2021-09-13 00:09:00           NaN           NaN          NaN          NaN
# 2021-09-13 00:10:00           NaN           NaN          NaN          NaN
# ...                           ...           ...          ...          ...
# 2021-11-03 23:55:00       7573.30       569.283          0.0          0.0
# 2021-11-03 23:56:00       7719.92       567.933          0.0          0.0
# 2021-11-03 23:57:00       7962.67       567.933          0.0          0.0
# 2021-11-03 23:58:00       8019.32       569.500          0.0          0.0
# 2021-11-03 23:59:00       8394.18       569.100          0.0          0.0
#
#                      PVT_kpec(We)  FC_kpec(We)  PlugLoad(We)  LightLoad(We)  \
# Time
# 2021-09-13 00:06:00         9.667        0.000       2492.71        640.722
# 2021-09-13 00:07:00           NaN          NaN           NaN            NaN
# 2021-09-13 00:08:00         9.552        0.000       2394.03        641.167
# 2021-09-13 00:09:00           NaN          NaN           NaN            NaN
# 2021-09-13 00:10:00           NaN          NaN           NaN            NaN
# ...                           ...          ...           ...            ...
# 2021-11-03 23:55:00         0.000      569.233       6000.10       1339.370
# 2021-11-03 23:56:00         0.000      567.933       6016.00       1470.630
# 2021-11-03 23:57:00         0.000      567.933       5963.23       1765.020
# 2021-11-03 23:58:00         0.000      569.500       6032.48       1751.720
# 2021-11-03 23:59:00         0.000      569.100       6414.50       1745.220
#
#                      FromGrid(We)  ToGrid(We)  ...  E_self(W)  E_self_acc(Wh)  \
# Time                                           ...
# 2021-09-13 00:06:00       5702.08         0.0  ...      9.667    1.611167e-01
# 2021-09-13 00:07:00           NaN         NaN  ...        NaN             NaN
# 2021-09-13 00:08:00       6580.36         0.0  ...      9.766    3.238833e-01
# 2021-09-13 00:09:00           NaN         NaN  ...        NaN             NaN
# 2021-09-13 00:10:00           NaN         NaN  ...        NaN             NaN
# ...                           ...         ...  ...        ...             ...
# 2021-11-03 23:55:00       7004.02         0.0  ...    569.283    4.444629e+06
# 2021-11-03 23:56:00       7151.98         0.0  ...    567.933    4.444639e+06
# 2021-11-03 23:57:00       7394.73         0.0  ...    567.933    4.444648e+06
# 2021-11-03 23:58:00       7449.82         0.0  ...    569.500    4.444657e+06
# 2021-11-03 23:59:00       7825.08         0.0  ...    569.100    4.444667e+06
#
#                      denominator  denominator_acc  SCF       LCF   SCF_acc  \
# Time
# 2021-09-13 00:06:00        9.667     1.611167e-01  1.0  0.001692  1.000000
# 2021-09-13 00:07:00          NaN              NaN  NaN       NaN       NaN
# 2021-09-13 00:08:00        9.766     3.238833e-01  1.0  0.001482  1.000000
# 2021-09-13 00:09:00          NaN              NaN  NaN       NaN       NaN
# 2021-09-13 00:10:00          NaN              NaN  NaN       NaN       NaN
# ...                          ...              ...  ...       ...       ...
# 2021-11-03 23:55:00      569.283     4.444629e+06  1.0  0.075170  0.451183
# 2021-11-03 23:56:00      567.933     4.444639e+06  1.0  0.073567  0.451184
# 2021-11-03 23:57:00      567.933     4.444648e+06  1.0  0.071324  0.451184
# 2021-11-03 23:58:00      569.500     4.444657e+06  1.0  0.071016  0.451185
# 2021-11-03 23:59:00      569.100     4.444667e+06  1.0  0.067797  0.451186
#
#                       LCF_acc  self_sustain  Avg_SCF&LCF
# Time
# 2021-09-13 00:06:00  0.001692      0.001692     0.500846
# 2021-09-13 00:07:00       NaN           NaN          NaN
# 2021-09-13 00:08:00  0.001580      0.001580     0.500790
# 2021-09-13 00:09:00       NaN           NaN          NaN
# 2021-09-13 00:10:00       NaN           NaN          NaN
# ...                       ...           ...          ...
# 2021-11-03 23:55:00  0.475555      1.057061     0.463369
# 2021-11-03 23:56:00  0.475549      1.057047     0.463367
# 2021-11-03 23:57:00  0.475544      1.057033     0.463364
# 2021-11-03 23:58:00  0.475538      1.057019     0.463361
# 2021-11-03 23:59:00  0.475532      1.057004     0.463359
#
# [74874 rows x 72 columns]

# %%
df_kpec.to_csv('./211108_kpec_tot.csv')

# %%
fig, ax = plt.subplots(figsize=(18,300))

for i in range(len(df_kpec.columns)):
    plt.subplot(len(df_kpec.columns), 1, i+1)
    plt.subplots_adjust(hspace=0.4)
    name = df_kpec.columns[i]
    plt.plot(df_kpec[name])    
    plt.title(name, loc = 'left', pad=15, fontsize=13, fontweight="bold")      
    plt.yticks(fontsize=13)    
    plt.xticks(fontsize=13)                
    plt.xlim(pd.Timestamp('2021-09-10'), pd.Timestamp('2021-11-05'))    
    plt.grid(True)
plt.show()
fig.tight_layout()

# %%
df = pd.read_csv('./211108_kpec_tot.csv', parse_dates = True)

# %%
df
# Out:
#                       Time  Cons_kpec(W)  Prod_kpec(W)  ESS_kpec(W)  \
# 0      2021-09-13 00:06:00       5711.75         9.667          0.0
# 1      2021-09-13 00:07:00           NaN           NaN          NaN
# 2      2021-09-13 00:08:00       6590.12         9.766          0.0
# 3      2021-09-13 00:09:00           NaN           NaN          NaN
# 4      2021-09-13 00:10:00           NaN           NaN          NaN
# ...                    ...           ...           ...          ...
# 74869  2021-11-03 23:55:00       7573.30       569.283          0.0
# 74870  2021-11-03 23:56:00       7719.92       567.933          0.0
# 74871  2021-11-03 23:57:00       7962.67       567.933          0.0
# 74872  2021-11-03 23:58:00       8019.32       569.500          0.0
# 74873  2021-11-03 23:59:00       8394.18       569.100          0.0
#
#        PV_kpec(We)  PVT_kpec(We)  FC_kpec(We)  PlugLoad(We)  LightLoad(We)  \
# 0              0.0         9.667        0.000       2492.71        640.722
# 1              NaN           NaN          NaN           NaN            NaN
# 2              0.0         9.552        0.000       2394.03        641.167
# 3              NaN           NaN          NaN           NaN            NaN
# 4              NaN           NaN          NaN           NaN            NaN
# ...            ...           ...          ...           ...            ...
# 74869          0.0         0.000      569.233       6000.10       1339.370
# 74870          0.0         0.000      567.933       6016.00       1470.630
# 74871          0.0         0.000      567.933       5963.23       1765.020
# 74872          0.0         0.000      569.500       6032.48       1751.720
# 74873          0.0         0.000      569.100       6414.50       1745.220
#
#        FromGrid(We)  ...  E_self(W)  E_self_acc(Wh)  denominator  \
# 0           5702.08  ...      9.667    1.611167e-01        9.667
# 1               NaN  ...        NaN             NaN          NaN
# 2           6580.36  ...      9.766    3.238833e-01        9.766
# 3               NaN  ...        NaN             NaN          NaN
# 4               NaN  ...        NaN             NaN          NaN
# ...             ...  ...        ...             ...          ...
# 74869       7004.02  ...    569.283    4.444629e+06      569.283
# 74870       7151.98  ...    567.933    4.444639e+06      567.933
# 74871       7394.73  ...    567.933    4.444648e+06      567.933
# 74872       7449.82  ...    569.500    4.444657e+06      569.500
# 74873       7825.08  ...    569.100    4.444667e+06      569.100
#
#        denominator_acc  SCF       LCF   SCF_acc   LCF_acc  self_sustain  \
# 0         1.611167e-01  1.0  0.001692  1.000000  0.001692      0.001692
# 1                  NaN  NaN       NaN       NaN       NaN           NaN
# 2         3.238833e-01  1.0  0.001482  1.000000  0.001580      0.001580
# 3                  NaN  NaN       NaN       NaN       NaN           NaN
# 4                  NaN  NaN       NaN       NaN       NaN           NaN
# ...                ...  ...       ...       ...       ...           ...
# 74869     4.444629e+06  1.0  0.075170  0.451183  0.475555      1.057061
# 74870     4.444639e+06  1.0  0.073567  0.451184  0.475549      1.057047
# 74871     4.444648e+06  1.0  0.071324  0.451184  0.475544      1.057033
# 74872     4.444657e+06  1.0  0.071016  0.451185  0.475538      1.057019
# 74873     4.444667e+06  1.0  0.067797  0.451186  0.475532      1.057004
#
#        Avg_SCF&LCF
# 0         0.500846
# 1              NaN
# 2         0.500790
# 3              NaN
# 4              NaN
# ...            ...
# 74869     0.463369
# 74870     0.463367
# 74871     0.463364
# 74872     0.463361
# 74873     0.463359
#
# [74874 rows x 73 columns]

# %%
df['Time']= pd.to_datetime(df['Time'])

# %%
fig, ax = plt.subplots(figsize=(18,300))


for i in range(len(df.columns)):
    plt.subplot(len(df.columns), 1, i+1)
    plt.subplots_adjust(hspace=0.4)
    plt.xlim(pd.Timestamp('2021-09-10'), pd.Timestamp('2021-11-05'))    
    name = df.columns[i]
    plt.scatter(x=df['Time'], y=df[name], s=3)   
    plt.title(name, loc = 'left', pad=15, fontsize=13, fontweight="bold")      
    plt.yticks(fontsize=13)    
    plt.xticks(fontsize=13)    
    plt.grid(True)
plt.show()
fig.tight_layout()
